# %%
import tensorflow as tf
import keras
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
from ml_data import SimpleHistData, DinucAutoCovarData, SequenceProteinData, SequenceNucsData, SequenceDinucProperties, SequenceMotifHot

# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

# %%
npath = "fasta/Ecoli_neg.fa"
ppath = "fasta/Ecoli_pos.fa"
data = SequenceDinucProperties(npath, ppath)

# %%
Xpos = data.get_positive_samples()
Xneg = data.get_negative_samples()
Y = data.getY()

print(Xpos.shape)
print(Xneg.shape)
print(Y.shape)
# Out:
# (839, 38, 79, 1)
# (3000, 38, 79, 1)
# (3839,)

# %%
def get_prop(df, i):
    return  pd.DataFrame(df[:,i,:,0], dtype='float')

# %%
prop = 3

# %%
plt.figure()
dfPos = get_prop(Xpos, prop)
ax = sns.violinplot(data=dfPos.iloc[:,41:61], palette="Set2", split=True, inner="quartile", scale="count", bw=.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
dfNeg = get_prop(Xneg, prop)
ax = sns.violinplot(data=dfNeg.iloc[:,41:61], palette="Set2", split=True, inner="quartile", scale="count", bw=.1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
plt.figure()
ax = sns.boxplot(data=dfPos)
ax = sns.lineplot(data=dfPos.mean(axis=0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax = sns.boxplot(data=dfNeg)
ax = sns.lineplot(data=dfNeg.mean(axis=0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
